# %%
import pandas as pd

# %%
crash_data = pd.read_csv('/workspaces/TechCatalyst_capston3/tableau/Collisions and Rides Dashboard (Crash Data)/Motor_Vehicle_Collisions Query.csv')
crash_data.head()
# Out:
#    CRASH DATE CRASH TIME        BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0  09/02/2023       6:22          BRONX   10459.0  40.829440  -73.89907
# 1  09/02/2023       0:00         QUEENS   11692.0  40.596153  -73.79896
# 2  09/02/2023       8:28      MANHATTAN   10001.0  40.757020  -74.00494
# 3  09/02/2023       3:37  STATEN ISLAND   10309.0  40.542152  -74.20350
# 4  09/02/2023       6:30      MANHATTAN   10014.0  40.739380  -74.00995
#
#                  LOCATION     ON STREET NAME CROSS STREET NAME  \
# 0   (40.82944, -73.89907)                NaN               NaN
# 1  (40.596153, -73.79896)                NaN               NaN
# 2   (40.75702, -74.00494)     WEST 34 STREET         12 AVENUE
# 3   (40.542152, -74.2035)       WOODROW ROAD     GILROY STREET
# 4   (40.73938, -74.00995)  GANSEVOORT STREET       WEST STREET
#
#              OFF STREET NAME  ...   CONTRIBUTING FACTOR VEHICLE 2  \
# 0     1224      UNION AVENUE  ...                             NaN
# ...

# %%
crash_data['CRASH TIME'] = pd.to_datetime(crash_data['CRASH TIME'])
# Out:
# /tmp/ipykernel_24976/3803935790.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   crash_data['CRASH TIME'] = pd.to_datetime(crash_data['CRASH TIME'])

# %%
crash_data['HOUR'] = crash_data['CRASH TIME'].dt.hour

# %%
crash_data['COLLISION_ID'].count()
# Out:
# np.int64(47484)

# %%
avg_collisions = crash_data.groupby(['BOROUGH', 'HOUR'])['COLLISION_ID'].count().reset_index()

# %%
avg_collisions
# Out:
#            BOROUGH  HOUR  COLLISION_ID
# 0            BRONX     0           313
# 1            BRONX     1           154
# 2            BRONX     2           126
# 3            BRONX     3           111
# 4            BRONX     4           135
# ..             ...   ...           ...
# 115  STATEN ISLAND    19            95
# 116  STATEN ISLAND    20            79
# 117  STATEN ISLAND    21            70
# 118  STATEN ISLAND    22            63
# 119  STATEN ISLAND    23            59
#
# [120 rows x 3 columns]

# %%
(((avg_collisions['COLLISION_ID']/47484)*100).round(2)).sum()
# Out:
# np.float64(99.96000000000001)

# %%
avg_collisions['Percent Increase'] = ((avg_collisions['COLLISION_ID']/47484)*100).round(2)
avg_collisions.columns = ['BOROUGH', 'HOUR', 'Avg Collision Count', 'Percent Increase']
avg_collisions
# Out:
#            BOROUGH  HOUR  Avg Collision Count  Percent Increase
# 0            BRONX     0                  313              0.66
# 1            BRONX     1                  154              0.32
# 2            BRONX     2                  126              0.27
# 3            BRONX     3                  111              0.23
# 4            BRONX     4                  135              0.28
# ..             ...   ...                  ...               ...
# 115  STATEN ISLAND    19                   95              0.20
# 116  STATEN ISLAND    20                   79              0.17
# 117  STATEN ISLAND    21                   70              0.15
# 118  STATEN ISLAND    22                   63              0.13
# 119  STATEN ISLAND    23                   59              0.12
#
# [120 rows x 4 columns]

# %%
avg_collisions['Percent Increase'].sum()
# Out:
# np.float64(99.96000000000001)

# %%
avg_collisions.sort_values('Percent Increase', ascending= False)
# Out:
#            BOROUGH  HOUR  Avg Collision Count  Percent Increase
# 41        BROOKLYN    17                 1087              2.29
# 40        BROOKLYN    16                 1084              2.28
# 39        BROOKLYN    15                 1023              2.15
# 38        BROOKLYN    14                  977              2.06
# 32        BROOKLYN     8                  960              2.02
# ..             ...   ...                  ...               ...
# 98   STATEN ISLAND     2                   41              0.09
# 99   STATEN ISLAND     3                   44              0.09
# 101  STATEN ISLAND     5                   45              0.09
# 97   STATEN ISLAND     1                   33              0.07
# 100  STATEN ISLAND     4                   26              0.05
#
# [120 rows x 4 columns]

# %%
avg_collisions.to_csv('borough_hour_pricing.csv', index = False)

# %%
bronx = avg_collisions[avg_collisions['BOROUGH'] == 'BRONX']
bronx
# Out:
#    BOROUGH  HOUR  Avg Collision Count  Percent Increase
# 0    BRONX     0                  313              0.66
# 1    BRONX     1                  154              0.32
# 2    BRONX     2                  126              0.27
# 3    BRONX     3                  111              0.23
# 4    BRONX     4                  135              0.28
# 5    BRONX     5                  134              0.28
# 6    BRONX     6                  199              0.42
# 7    BRONX     7                  324              0.68
# 8    BRONX     8                  451              0.95
# 9    BRONX     9                  307              0.65
# 10   BRONX    10                  270              0.57
# 11   BRONX    11                  326              0.69
# 12   BRONX    12                  352              0.74
# 13   BRONX    13                  332              0.70
# 14   BRONX    14                  441              0.93
# 15   BRONX    15                  452              0.95
# ...
